# %%
# Importar las librerias
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import pandas as pd
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt

# %%
# Carga los datos en dos dataframe
dataIris = load_iris()
dfXDataIris = pd.DataFrame(dataIris['data'])
dfYDataIris = pd.DataFrame(dataIris['target'])

# %%
# Visualizar la información descriptiva de los datos
print(dfXDataIris.describe())
print(dfYDataIris.describe())
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000
#                 0
# count  150.000000
# mean     1.000000
# std      0.819232
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
# Visualizar la información
pd.plotting.scatter_matrix(dfXDataIris, c=dfYDataIris, diagonal='kde')
# Out:
# array([[<Axes: xlabel='0', ylabel='0'>, <Axes: xlabel='1', ylabel='0'>,
#         <Axes: xlabel='2', ylabel='0'>, <Axes: xlabel='3', ylabel='0'>],
#        [<Axes: xlabel='0', ylabel='1'>, <Axes: xlabel='1', ylabel='1'>,
#         <Axes: xlabel='2', ylabel='1'>, <Axes: xlabel='3', ylabel='1'>],
#        [<Axes: xlabel='0', ylabel='2'>, <Axes: xlabel='1', ylabel='2'>,
#         <Axes: xlabel='2', ylabel='2'>, <Axes: xlabel='3', ylabel='2'>],
#        [<Axes: xlabel='0', ylabel='3'>, <Axes: xlabel='1', ylabel='3'>,
#         <Axes: xlabel='2', ylabel='3'>, <Axes: xlabel='3', ylabel='3'>]],
#       dtype=object)

# %%
# Entrena el modelo con 2, 3, 4, 5 y 6 clusters
modeloKmeans = [ KMeans(n_clusters=i, init='random', n_init=10).fit(dfXDataIris) for i in range(2,6) ]

# %%
# Crea las etiquetas de cada clusters
etiquetas = [f"cluster_{i}" for i in range(2, 6)]
predicciones = np.array([ k.predict(dfXDataIris) for k in modeloKmeans])

for i in range(2, 6):
    pd.plotting.scatter_matrix(dfXDataIris, c=predicciones[i-2])
    plt.suptitle(f"Numero clusters = {i}")

# %%
# Out:
# Iteracion 2
# Iteracion 3
# Iteracion 4
# Iteracion 5
